# %%
import requests
import pandas as pd
import json

# %%
url = "https://api.yelp.com/v3/businesses/search"
API_Key = 'r49httaF_orDBSfiWTEHUl8qY8m5D10OKMYizHVtv8aSEbAcbXMinaqcDOZCCa3mzJ8D2MZU7a9vTeKFs6OmGyScxLtUa73AMqRt8PLoOkhEx1fTvpA6br3bd2EJYnYx'

# %%
params = {
    'term':'Restaurants',
    'location':'32607',
    'radius':'20000',
    'limit':'50',
    'offset':'51',
    'sort_by':'rating'
}
headers = {
    'Authorization': 'Bearer %s' % API_Key,
    'Content-Type':'application/json'
}

# %%
response = requests.get(url,params=params,headers=headers)

# %%
print(response)
# Out:
# <Response [200]>

# %%
response.json().keys()
# Out:
# dict_keys(['businesses', 'total', 'region'])

# %%
df1 =pd.DataFrame(response.json()['businesses'])

# %%
df0.head()
# Out:
#                        id                                         alias  \
# 0  Xl9sx4-R4lKGS7fmdb8Qng               la-cocina-de-abuela-gainesville
# 1  ApIy8nWtjCBlOtSekj7kmg                     prums-kitchen-gainesville
# 2  XYafZWbuNGAUocMauELYGQ  maple-street-biscuit-gainesville-gainesville
# 3  zA3B8OS-p_OQsCUy6VliKA                       daily-green-gainesville
# 4  0nfh1ow8Qsq0iZhDi5cDhA                       blaze-pizza-gainesville
#
#                                  name  \
# 0                 La Cocina De Abuela
# 1                      Prum's kitchen
# 2  Maple Street Biscuit - Gainesville
# 3                         Daily Green
# 4                         Blaze Pizza
#
#                                            image_url  is_closed  \
# 0  https://s3-media2.fl.yelpcdn.com/bphoto/HyMlLL...      False
# 1  https://s3-media4.fl.yelpcdn.com/bphoto/ZAVx6b...      False
# 2  https://s3-media4.fl.yelpcdn.com/bphoto/QrNIjl...      False
# ...

# %%
df1.head()
# Out:
#                        id                                              alias  \
# 0  BtfJ4BYuXFj6rfEc_kb5zg                covey-kitchen-cocktails-gainesville
# 1  Zg4bgi4-GUQxtZ0riKv6-Q                               tony-and-als-alachua
# 2  LOgDnd_-9iUa-mCEZ8EoEg       dick-mondell-s-burgers-and-fries-gainesville
# 3  0QCuSX3oiTQEvR795kNUBg                        mi-apá-latin-cafe-alachua-4
# 4  impyjZI_Kwh-ykvjWjrw0Q  43rd-street-deli-and-breakfast-house-gainesvil...
#
#                                  name  \
# 0           Covey Kitchen + Cocktails
# 1                       Tony and Al's
# 2      Dick Mondell’s Burgers & Fries
# 3                   Mi Apá Latin Cafe
# 4  43rd Street Deli & Breakfast House
#
#                                            image_url  is_closed  \
# 0  https://s3-media4.fl.yelpcdn.com/bphoto/bhvsOF...      False
# 1  https://s3-media2.fl.yelpcdn.com/bphoto/lL_u93...      False
# 2  https://s3-media1.fl.yelpcdn.com/bphoto/y8ZYo0...      False
# ...

# %%
df_100 = pd.concat([df0,df1],ignore_index=True)

# %%
df_100.shape
# Out:
# (100, 16)

# %%
df_100.to_csv('top_100_local.csv')
